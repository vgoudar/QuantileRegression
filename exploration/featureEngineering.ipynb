# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import pickle
import copy

from sklearn.impute import SimpleImputer
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_pinball_loss

from sklearn.metrics import r2_score

import xgboost as xgb
from hyperopt import STATUS_OK, Trials, fmin, hp, tpe

# %%
path = '../DATA'
trainFile = 'train_augmented.csv'
testFile = 'test_augmented.csv'

# %%
# Load all data
train_df = pd.read_csv(os.path.join(path, trainFile),
                       header = 0,
                       index_col='id')
test_df = pd.read_csv(os.path.join(path, testFile),
                      header = 0,
                      index_col='id')

# %% [markdown]
# ## Transform categorical (and ordinal) variables

# %%
# occupation, marital status, state, region, race, urban are categorical variables, education is an ordinal variable.
train_df['educationCat'] = train_df['education']
test_df['educationCat'] = test_df['education']


catCols = ['region', 'state', 'marital', 'occupation','urban', 'race']

#xgboost expects categoricals starting at 0
train_df[catCols] = train_df[catCols] - 1
test_df[catCols] = test_df[catCols] - 1

catCols.append('educationCat')
train_df[catCols] = train_df[catCols].astype('category')
test_df[catCols] = test_df[catCols].astype('category')

# %% [markdown]
# ## Set data types to float

# %%
numericalCols = ['year', 'month', 'age', 'education', 'familysize', 'income','daysInMonth',
                     'daysInPrevMonth', 'CPIUrban', 'LaborForceParticip',
                     'UnemploymentRateByAge', 'AnnualExpenditureByAge',
                     'AnnualExpenditureByIncome', 'AnnualExpenditureByFamilySize']

# Convert to float
train_df[numericalCols] = train_df[numericalCols].astype('float')
test_df[numericalCols] = test_df[numericalCols].astype('float')

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# Due to time constraints, I will skip feature selection. More on this with xgb!

# %%
# features added from earlier version of code, based on vanilla sklearn quantile regression

train_df['education_per_familySize'] = train_df['education']/train_df['familysize']
train_df['age_per_familySize'] =  train_df['age']/train_df['familysize']
train_df['education_per_income'] =  train_df['education']/(train_df['income']+1)

test_df['education_per_familySize'] = test_df['education']/test_df['familysize']
test_df['age_per_familySize'] =  test_df['age']/test_df['familysize']
test_df['education_per_income'] =  test_df['education']/(test_df['income']+1)

numericalCols.extend(['education_per_familySize',
                'age_per_familySize',
                'education_per_income'])

# Convert to float
train_df[numericalCols] = train_df[numericalCols].astype('float')
test_df[numericalCols] = test_df[numericalCols].astype('float')

# %% [markdown]
# ### Get individual feature mutual information

# %%
from sklearn.feature_selection import mutual_info_regression as mi_reg

catCols_nonNull = ['marital', 'urban', 'race', 'educationCat']
mi_cat = mi_reg(X_train[catCols_nonNull], y_train, discrete_features=True)

mi_cat_nulls = []
for cols in ['region', 'state', 'occupation']:
    X_tmp = X_train[cols]
    y_tmp = y_train[X_tmp.notna()]
    X_tmp = X_tmp[X_tmp.notna()]
    mi_cat_nulls.append(mi_reg(X_tmp.to_frame(), y_tmp, discrete_features=True))
mi_cat_nulls = np.array(mi_cat_nulls).flatten()

numericalCols = ['year', 'month', 'age', 'education', 'familysize', 'income','daysInMonth',
                     'daysInPrevMonth', 'CPIUrban', 'LaborForceParticip',
                     'UnemploymentRateByAge', 'AnnualExpenditureByAge',
                     'AnnualExpenditureByIncome', 'AnnualExpenditureByFamilySize']
numericalCols.extend(['education_per_familySize','age_per_familySize','education_per_income'])
mi_num = mi_reg(X_train[numericalCols], y_train, discrete_features=False)

# %%
cols_all = copy.copy(catCols_nonNull)
cols_all.extend(['region', 'state', 'occupation'])
cols_all.extend(numericalCols)
mis = np.concatenate((mi_cat, mi_cat_nulls, mi_num), axis=0)
mi_df = pd.DataFrame(data={'feature':cols_all, 'mi': mis})

mi_df.head(len(cols_all))
# Out:
#                           feature        mi
# 0                         marital  0.084945
# 1                           urban  0.003023
# 2                            race  0.011005
# 3                    educationCat  0.074966
# 4                          region  0.006312
# 5                           state  0.020226
# 6                      occupation  0.056487
# 7                            year  0.021980
# 8                           month  0.011270
# 9                             age  0.060308
# 10                      education  0.079910
# 11                     familysize  0.082344
# 12                         income  0.307439
# 13                    daysInMonth  0.005383
# 14                daysInPrevMonth  0.004166
# 15                       CPIUrban  0.043453
# 16             LaborForceParticip  0.023345
# 17          UnemploymentRateByAge  0.024438
# 18         AnnualExpenditureByAge  0.076354
# 19      AnnualExpenditureByIncome  0.302287
# 20  AnnualExpenditureByFamilySize  0.111136
# 21       education_per_familySize  0.156588
# 22             age_per_familySize  0.095405
# 23           education_per_income  0.270080

# %% [markdown]
# ### Get crosses (multiplication, division) for numerical features and their mutual information
#
# I evaluated how helpful a feature may be via a mutual information-based heuristic (to save time compared to using the model to select cross features).

# %%
c1 = []
c1_val = []
c2_val = []
c2 = []
p = []
d1 = []
d2 = []
for i1, col1 in enumerate(numericalCols):
    for i2, col2 in enumerate(numericalCols):
        if i2 < i1:
            continue
        prod = (X_train[col1]+1)*(X_train[col2]+1)
        div1 = (X_train[col1]+1)/(X_train[col2]+1)
        div2 = (X_train[col2]+1)/(X_train[col1]+1)
        c1.append(col1)
        c1_val.append(mi_df.loc[mi_df['feature']==col1,:]['mi'].values[0])
        c2_val.append(mi_df.loc[mi_df['feature']==col2,:]['mi'].values[0])
        c2.append(col2)
        p.append(mi_reg(prod.to_frame(), y_train, discrete_features=False))
        d1.append(mi_reg(prod.to_frame(), y_train, discrete_features=False))
        d2.append(mi_reg(prod.to_frame(), y_train, discrete_features=False))

# %%
mi_df_num_cross = pd.DataFrame(data={'c1':c1, 'c2':c2, 'c1_val':c1_val, 'c2_val':c2_val, 'p':p, 'd1':d1, 'd2': d2})

# %%
mi_df_num_cross['improvement_p'] = mi_df_num_cross['p'] - mi_df_num_cross[['c1_val', 'c2_val']].max(axis=1)
mi_df_num_cross['improvement_d1'] = mi_df_num_cross['d1'] - mi_df_num_cross[['c1_val', 'c2_val']].max(axis=1)
mi_df_num_cross['improvement_d2'] = mi_df_num_cross['d2'] - mi_df_num_cross[['c1_val', 'c2_val']].max(axis=1)
mi_df_num_cross = mi_df_num_cross.sort_values(by=['improvement_d2'], ascending=False)
with pd.option_context('display.max_rows', None):  
    display(mi_df_num_cross)
# Out:
#                                 c1                             c2    c1_val  \
# 58                       education  AnnualExpenditureByFamilySize  0.079910
# 49                       education                     familysize  0.079910
# 69                      familysize         AnnualExpenditureByAge  0.082344
# 56                       education         AnnualExpenditureByAge  0.079910
# 66                      familysize                       CPIUrban  0.082344
# 61                       education           education_per_income  0.079910
# 10                            year          UnemploymentRateByAge  0.021980
# 118             LaborForceParticip          UnemploymentRateByAge  0.023345
# 4                             year                     familysize  0.021980
# 67                      familysize             LaborForceParticip  0.082344
# 2                             year                            age  0.021980
# 34                             age                      education  0.060308
# 53                       education                       CPIUrban  0.079910
# 14                            year       education_per_familySize  0.021980
# 15                            year             age_per_familySize  0.021980
# 3                             year                      education  0.021980
# 110                       CPIUrban          UnemploymentRateByAge  0.043453
# 60                       education             age_per_familySize  0.079910
# 46                             age             age_per_familySize  0.060308
# 54                       education             LaborForceParticip  0.079910
# 25                           month             LaborForceParticip  0.011270
# 40                             age             LaborForceParticip  0.060308
# 113                       CPIUrban  AnnualExpenditureByFamilySize  0.043453
# 83                          income  AnnualExpenditureByFamilySize  0.307439
# 39                             age                       CPIUrban  0.060308
# 26                           month          UnemploymentRateByAge  0.011270
# 35                             age                     familysize  0.060308
# 59                       education       education_per_familySize  0.079910
# 144  AnnualExpenditureByFamilySize       education_per_familySize  0.111136
# 111                       CPIUrban         AnnualExpenditureByAge  0.043453
# 74                      familysize           education_per_income  0.082344
# 101                daysInPrevMonth          UnemploymentRateByAge  0.004166
# 91                     daysInMonth          UnemploymentRateByAge  0.005383
# 9                             year             LaborForceParticip  0.021980
# 149       education_per_familySize           education_per_income  0.156588
# 7                             year                daysInPrevMonth  0.021980
# 6                             year                    daysInMonth  0.021980
# 100                daysInPrevMonth             LaborForceParticip  0.004166
# 121             LaborForceParticip  AnnualExpenditureByFamilySize  0.023345
# 90                     daysInMonth             LaborForceParticip  0.005383
# 136         AnnualExpenditureByAge             age_per_familySize  0.076354
# 57                       education      AnnualExpenditureByIncome  0.079910
# 65                      familysize                daysInPrevMonth  0.082344
# 73                      familysize             age_per_familySize  0.082344
# 64                      familysize                    daysInMonth  0.082344
# 50                       education                         income  0.079910
# 78                          income                       CPIUrban  0.307439
# 119             LaborForceParticip         AnnualExpenditureByAge  0.023345
# 103                daysInPrevMonth      AnnualExpenditureByIncome  0.004166
# 93                     daysInMonth      AnnualExpenditureByIncome  0.005383
# 104                daysInPrevMonth  AnnualExpenditureByFamilySize  0.004166
# 88                     daysInMonth                daysInPrevMonth  0.005383
# 82                          income      AnnualExpenditureByIncome  0.307439
# 94                     daysInMonth  AnnualExpenditureByFamilySize  0.005383
# 92                     daysInMonth         AnnualExpenditureByAge  0.005383
# 37                             age                    daysInMonth  0.060308
# 51                       education                    daysInMonth  0.079910
# 102                daysInPrevMonth         AnnualExpenditureByAge  0.004166
# 38                             age                daysInPrevMonth  0.060308
# 33                             age                            age  0.060308
# 5                             year                         income  0.021980
# 24                           month                       CPIUrban  0.011270
# 22                           month                    daysInMonth  0.011270
# 125          UnemploymentRateByAge          UnemploymentRateByAge  0.024438
# 52                       education                daysInPrevMonth  0.079910
# 98                 daysInPrevMonth                daysInPrevMonth  0.004166
# 8                             year                       CPIUrban  0.021980
# 99                 daysInPrevMonth                       CPIUrban  0.004166
# 109                       CPIUrban             LaborForceParticip  0.043453
# 108                       CPIUrban                       CPIUrban  0.043453
# 71                      familysize  AnnualExpenditureByFamilySize  0.082344
# 89                     daysInMonth                       CPIUrban  0.005383
# 62                      familysize                     familysize  0.082344
# 23                           month                daysInPrevMonth  0.011270
# 87                     daysInMonth                    daysInMonth  0.005383
# 86                          income           education_per_income  0.307439
# 117             LaborForceParticip             LaborForceParticip  0.023345
# 42                             age         AnnualExpenditureByAge  0.060308
# 147       education_per_familySize       education_per_familySize  0.156588
# 150             age_per_familySize             age_per_familySize  0.095405
# 44                             age  AnnualExpenditureByFamilySize  0.060308
# 123             LaborForceParticip             age_per_familySize  0.023345
# 107                daysInPrevMonth           education_per_income  0.004166
# 81                          income         AnnualExpenditureByAge  0.307439
# 152           education_per_income           education_per_income  0.270080
# 75                          income                         income  0.307439
# 96                     daysInMonth             age_per_familySize  0.005383
# 95                     daysInMonth       education_per_familySize  0.005383
# 105                daysInPrevMonth       education_per_familySize  0.004166
# 97                     daysInMonth           education_per_income  0.005383
# 48                       education                      education  0.079910
# 106                daysInPrevMonth             age_per_familySize  0.004166
# 122             LaborForceParticip       education_per_familySize  0.023345
# 55                       education          UnemploymentRateByAge  0.079910
# 70                      familysize      AnnualExpenditureByIncome  0.082344
# 17                           month                          month  0.011270
# 63                      familysize                         income  0.082344
# 0                             year                           year  0.021980
# 79                          income             LaborForceParticip  0.307439
# 77                          income                daysInPrevMonth  0.307439
# 126          UnemploymentRateByAge         AnnualExpenditureByAge  0.024438
# 120             LaborForceParticip      AnnualExpenditureByIncome  0.023345
# 19                           month                      education  0.011270
# 76                          income                    daysInMonth  0.307439
# 142      AnnualExpenditureByIncome           education_per_income  0.302287
# 32                           month           education_per_income  0.011270
# 115                       CPIUrban             age_per_familySize  0.043453
# 134         AnnualExpenditureByAge  AnnualExpenditureByFamilySize  0.076354
# 112                       CPIUrban      AnnualExpenditureByIncome  0.043453
# 72                      familysize       education_per_familySize  0.082344
# 68                      familysize          UnemploymentRateByAge  0.082344
# 130          UnemploymentRateByAge             age_per_familySize  0.024438
# 114                       CPIUrban       education_per_familySize  0.043453
# 1                             year                          month  0.021980
# 143  AnnualExpenditureByFamilySize  AnnualExpenditureByFamilySize  0.111136
# 18                           month                            age  0.011270
# 13                            year  AnnualExpenditureByFamilySize  0.021980
# 128          UnemploymentRateByAge  AnnualExpenditureByFamilySize  0.024438
# 145  AnnualExpenditureByFamilySize             age_per_familySize  0.111136
# 132         AnnualExpenditureByAge         AnnualExpenditureByAge  0.076354
# 148       education_per_familySize             age_per_familySize  0.156588
# 11                            year         AnnualExpenditureByAge  0.021980
# 135         AnnualExpenditureByAge       education_per_familySize  0.076354
# 20                           month                     familysize  0.011270
# 45                             age       education_per_familySize  0.060308
# 31                           month             age_per_familySize  0.011270
# 41                             age          UnemploymentRateByAge  0.060308
# 146  AnnualExpenditureByFamilySize           education_per_income  0.111136
# 47                             age           education_per_income  0.060308
# 30                           month       education_per_familySize  0.011270
# 36                             age                         income  0.060308
# 80                          income          UnemploymentRateByAge  0.307439
# 129          UnemploymentRateByAge       education_per_familySize  0.024438
# 27                           month         AnnualExpenditureByAge  0.011270
# 137         AnnualExpenditureByAge           education_per_income  0.076354
# 29                           month  AnnualExpenditureByFamilySize  0.011270
# 131          UnemploymentRateByAge           education_per_income  0.024438
# 140      AnnualExpenditureByIncome       education_per_familySize  0.302287
# 139      AnnualExpenditureByIncome  AnnualExpenditureByFamilySize  0.302287
# 151             age_per_familySize           education_per_income  0.095405
# 21                           month                         income  0.011270
# 12                            year      AnnualExpenditureByIncome  0.021980
# 84                          income       education_per_familySize  0.307439
# 43                             age      AnnualExpenditureByIncome  0.060308
# 133         AnnualExpenditureByAge      AnnualExpenditureByIncome  0.076354
# 127          UnemploymentRateByAge      AnnualExpenditureByIncome  0.024438
# 116                       CPIUrban           education_per_income  0.043453
# 138      AnnualExpenditureByIncome      AnnualExpenditureByIncome  0.302287
# 124             LaborForceParticip           education_per_income  0.023345
# 85                          income             age_per_familySize  0.307439
# 16                            year           education_per_income  0.021980
# 141      AnnualExpenditureByIncome             age_per_familySize  0.302287
# 28                           month      AnnualExpenditureByIncome  0.011270
#
#        c2_val                       p                       d1  \
# 58   0.111136   [0.20130854532278075]     [0.2015601665459128]
# 49   0.082344    [0.1644119544841942]    [0.16553796247686137]
# 69   0.076354   [0.14311665730090883]    [0.14295186092157763]
# 56   0.076354   [0.13901528056569923]     [0.1389896835860851]
# 66   0.043453   [0.12573229115339046]     [0.1260110348617811]
# 61   0.270080   [0.30934058261366637]    [0.30964088537137435]
# 10   0.024438   [0.06214664074717202]   [0.062134347337459594]
# 118  0.024438  [0.062394282963177616]     [0.0620216390807693]
# 4    0.082344    [0.1112212389425018]    [0.11175625046750692]
# 67   0.023345   [0.11014444129576706]    [0.10931825041263554]
# 2    0.060308   [0.08796972465589015]    [0.08822239350285965]
# 34   0.079910   [0.10782965438110814]    [0.10720580328750273]
# 53   0.043453   [0.10714797251074071]    [0.10706039080637986]
# 14   0.156588    [0.1837104344584608]    [0.18352848506799635]
# 15   0.095405   [0.12132420011590739]    [0.12136640784835162]
# 3    0.079910    [0.1048300642671105]    [0.10417154080955271]
# 110  0.024438   [0.06663756155109901]    [0.06677392064338417]
# 60   0.095405    [0.1182507151192933]    [0.11808735910592816]
# 46   0.095405   [0.11656325870307427]    [0.11622058151019932]
# 54   0.023345   [0.09833437469498385]    [0.09878084192380943]
# 25   0.023345   [0.04162262312213727]     [0.0418441367060467]
# 40   0.023345    [0.0759865605253296]    [0.07603781437510371]
# 113  0.111136   [0.12591406846824782]     [0.1261622730212677]
# 83   0.111136    [0.3219509014190569]     [0.3220770763897267]
# 39   0.043453   [0.07451834743221308]    [0.07442109021603294]
# 26   0.024438  [0.038605605426970335]   [0.037935107951462044]
# 35   0.082344   [0.09532467789418231]    [0.09549555332849291]
# 59   0.156588   [0.16795948380028047]    [0.16781324614166415]
# 144  0.156588   [0.16930854877205181]    [0.16896191262965043]
# 111  0.076354   [0.08776845582239723]    [0.08780184332072238]
# 74   0.270080    [0.2820822465604005]    [0.28218724374299864]
# 43    [0.16699797580272602]     [-0.13530862814190225]
# 133    [0.1605988584294944]     [-0.14202162387603412]
# 127    [0.1530894092826678]     [-0.14884242938756387]
# 116    [0.1000314073575499]     [-0.17026832064036945]
# 138   [0.12422308696119488]     [-0.17675994756933644]
# 124   [0.07891759827048261]     [-0.19161853438155063]
# 85    [0.11545263059019817]     [-0.19198448907179255]
# 16    [0.07205126129492623]      [-0.1981297094700798]
# 141   [0.09187614889120344]      [-0.2102768301048803]
# 28    [0.06828697124120042]     [-0.23505930831473343]
#
#                 improvement_d1             improvement_d2
# 58       [0.09042462003082985]      [0.09075836560330863]
# 49       [0.08319430048791121]      [0.08296007606432587]
# 69       [0.06060819893262748]      [0.06074001359641512]
# 56      [0.059079431190542486]      [0.05847627320512938]
# 66      [0.043667372872830956]      [0.04373413097211598]
# 61      [0.039560494462232754]      [0.03918559571173219]
# 10       [0.03769662822457498]     [0.037731426929585865]
# 118      [0.03758391996788468]      [0.03728075252116181]
# 4       [0.029412588478556767]      [0.02863234949778315]
# 67      [0.026974588423685386]      [0.02776470569992151]
# 2       [0.027914584216214955]      [0.02754837795970122]
# 34       [0.02729555089196012]     [0.027243393372745395]
# 53      [0.027150138410837243]     [0.027183271222382288]
# 14       [0.02694094617938525]     [0.027149957248109757]
# 15      [0.025961807629593103]      [0.02541325085031243]
# 3       [0.024261288414010096]     [0.025155246382309926]
# 110      [0.02332117690326818]     [0.023051704794132988]
# 60       [0.02268275888716964]     [0.022589972520988155]
# 46        [0.0208159812914408]      [0.02124120331946866]
# 54      [0.018870589528266812]      [0.01872666833287706]
# 25      [0.018499315521588677]      [0.01805875965430026]
# 40       [0.01573000508845901]     [0.015517858707513987]
# 113     [0.015026726506184751]     [0.014837275818361029]
# 83      [0.014637611509205506]     [0.014410901747398341]
# 39      [0.014113280929388239]     [0.014124136086571148]
# 26      [0.013497388838577429]     [0.013642453601143245]
# 35      [0.013151891339542754]     [0.012760000268575933]
# 59      [0.011225707253053052]     [0.012650295828761315]
# 144     [0.012374373741039335]     [0.012093620048040599]
# 111      [0.01144818789309543]     [0.012010276910574547]
# 74       [0.01210685283385704]     [0.011720735177698671]
# 101     [0.010498606109619502]      [0.01105176104952843]
# 91       [0.01120726118890314]      [0.01058710698497034]
# 9       [0.011296191159308577]     [0.010351593304061879]
# 149     [0.009614675985178955]     [0.009463705609828565]
# 7       [0.007507677412192493]     [0.008812664907465795]
# 6        [0.00751181715484428]      [0.00868333443854219]
# 100      [0.00807779054224067]     [0.008433587829989264]
# 121     [0.007731327288445833]     [0.008024592721056933]
# 90      [0.008399426015840206]     [0.007455103406740271]
# 136     [0.007612430047863938]     [0.007302210968795464]
# 57     [0.0074934125024892495]     [0.007239667282428641]
# 65      [0.005607602658920019]     [0.006665397421250052]
# 73      [0.006645784340505223]     [0.006495721293654277]
# 64     [0.0038561525052238643]     [0.005633100656133205]
# 50      [0.005320616973375714]     [0.005359297250114636]
# 78      [0.005199268419589842]    [0.0053590240427139335]
# 119    [0.0048700270377581845]     [0.005280131425566381]
# * CPIUrban (inflation) times familySize
#
# As noted above, a previous version of the code tested other pre-augmentation crosses on vanilla quantile regression and found these to be relevant:
# * education per familySize
# * age per familySize
# * education per income

# %% [markdown]
# ### Get crosses (conjunction) for categorical features and their mutual information

# %%
c1 = []
c1_val = []
c2_val = []
c2 = []
p = []
for i1, col1 in enumerate(catCols):
    for i2, col2 in enumerate(catCols):
        if i2 <= i1:
            continue
            v1 = X_train[col1].dropna().unique()
            v2 = X_train[col2].dropna().unique()
            v1 = pd.Series(v1, name = col1)
            v2 = pd.Series(v2, name = col2)
            c_df = pd.merge(v1, v2,how='cross')
            c_df['index1'] = c_df.index
            y_train2 = y_train[(X_train[col1].notna()) & (X_train[col2].notna())]
            X_train2 = X_train[(X_train[col1].notna()) & (X_train[col2].notna())]
            m_df = pd.merge(X_train2, c_df, on=[col1, col2])
            c1.append(col1)
            c1_val.append(mi_df.loc[mi_df['feature']==col1,:]['mi'].values[0])
            c2_val.append(mi_df.loc[mi_df['feature']==col2,:]['mi'].values[0])
            c2.append(col2)
            p.append(mi_reg(m_df['index1'].to_frame(), y_train2, discrete_features=True))

# %%
mi_df_cat_cross = pd.DataFrame(data={'c1':c1, 'c2':c2, 'c1_val':c1_val, 'c2_val':c2_val, 'p':p})
mi_df_cat_cross['improvement_p'] = mi_df_cat_cross['p'] - mi_df_cat_cross[['c1_val', 'c2_val']].max(axis=1)
mi_df_cat_cross = mi_df_cat_cross.sort_values(by=['improvement_p'], ascending=False)
with pd.option_context('display.max_rows', None):  
    display(mi_df_cat_cross)
# Out:
#             c1            c2    c1_val    c2_val                         p  \
# 3       region         urban  0.006312  0.003023                       [0]
# 18       urban          race  0.003023  0.011005   [0.0013720779019432694]
# 4       region          race  0.006312  0.011005                       [0]
# 0       region         state  0.006312  0.020226                       [0]
# 8        state         urban  0.020226  0.003023                       [0]
# 9        state          race  0.020226  0.011005                       [0]
# 2       region    occupation  0.006312  0.056487   [0.0021239435450493005]
# 7        state    occupation  0.020226  0.056487   [0.0012639514716399347]
# 15  occupation         urban  0.056487  0.003023   [0.0011314227205860838]
# 16  occupation          race  0.056487  0.011005   [0.0009707974564427957]
# 20        race  educationCat  0.011005  0.074966   [0.0004655368879782351]
# 10       state  educationCat  0.020226  0.074966  [0.00016738216458644928]
# 17  occupation  educationCat  0.056487  0.074966   [8.532794380844422e-05]
# 5       region  educationCat  0.006312  0.074966                       [0]
# 19       urban  educationCat  0.003023  0.074966                       [0]
# 13     marital          race  0.084945  0.011005   [0.0011472427202519064]
# 11     marital    occupation  0.084945  0.056487   [0.0007000421871818929]
# 1       region       marital  0.006312  0.084945   [0.0006394865646717207]
# 12     marital         urban  0.084945  0.003023  [0.00020842806926379964]
# 14     marital  educationCat  0.084945  0.074966                       [0]
# 6        state       marital  0.020226  0.084945                       [0]
#
#               improvement_p
# 3   [-0.006312160774230247]
# 18  [-0.009632990355563864]
# 4   [-0.011005068257507133]
# 0   [-0.020226115694808477]
# 8   [-0.020226115694808477]
# 9   [-0.020226115694808477]
# 2    [-0.05436303760781902]
# 7   [-0.055223029681228386]
# 15   [-0.05535555843228224]
# 16  [-0.055516183696425525]
# 20   [-0.07450032767673198]
# 10   [-0.07479848240012377]
# 17   [-0.07488053662090177]
# 5    [-0.07496586456471022]
# 19   [-0.07496586456471022]
# 13   [-0.08379765236182068]
# 11    [-0.0842448528948907]
# 1    [-0.08430540851740087]
# 12   [-0.08473646701280879]
# 14   [-0.08494489508207259]
# 6    [-0.08494489508207259]

# %% [markdown]
# None of these seem like they would help.

# %% [markdown]
# ### Add in new features
#
# Note that we will also be:
# * applying a cyclical transformation to month
# * replacing high cardinality categories with target encoding

# %%
# Start over
# Reload all data
train_df = pd.read_csv(os.path.join(path, trainFile),
                       header = 0,
                       index_col='id')
test_df = pd.read_csv(os.path.join(path, testFile),
                      header = 0,
                      index_col='id')

# occupation, marital status, state, region, race, urban are categorical variables, education is an ordinal variable.
train_df['educationCat'] = train_df['education']
test_df['educationCat'] = test_df['education']


catCols = ['region', 'state', 'marital', 'occupation','urban', 'race']

#xgboost expects categoricals starting at 0
train_df[catCols] = train_df[catCols] - 1
test_df[catCols] = test_df[catCols] - 1

catCols.append('educationCat')
train_df[catCols] = train_df[catCols].astype('category')
test_df[catCols] = test_df[catCols].astype('category')

numericalCols = ['year', 'month', 'age', 'education', 'familysize', 'income','daysInMonth',
                     'daysInPrevMonth', 'CPIUrban', 'LaborForceParticip',
                     'UnemploymentRateByAge', 'AnnualExpenditureByAge',
                     'AnnualExpenditureByIncome', 'AnnualExpenditureByFamilySize']

# Convert to float
train_df[numericalCols] = train_df[numericalCols].astype('float')
test_df[numericalCols] = test_df[numericalCols].astype('float')

# %%
numericalCols = ['year', 'month', 'age', 'education', 'familysize', 'income','daysInMonth',
                     'daysInPrevMonth', 'CPIUrban', 'LaborForceParticip',
                     'UnemploymentRateByAge', 'AnnualExpenditureByAge',
                     'AnnualExpenditureByIncome', 'AnnualExpenditureByFamilySize']

catCols = ['region', 'state', 'marital', 'occupation','urban', 'race','educationCat']

newNumCols = []
remNumCols = []
remCatCols = []
# circular encoding of months
train_df['month_s'] = np.sin(2 * np.pi * (train_df['month']-1)/11.0)
train_df['month_c'] = np.cos(2 * np.pi * (train_df['month']-1)/11.0)
train_df = train_df.drop(columns=['month'])

test_df['month_s'] = np.sin(2 * np.pi * (test_df['month']-1)/11.0)
test_df['month_c'] = np.cos(2 * np.pi * (test_df['month']-1)/11.0)
test_df = test_df.drop(columns=['month'])

newNumCols.extend(['month_s','month_c'])
remNumCols.append('month')

# target encoding of categorical variables with high cardinality i.e. state and cardinality
f_list = ['mean',
         lambda x: np.quantile(x, 0.1),
         lambda x: np.quantile(x, 0.25),
         lambda x: np.quantile(x, 0.5),
         lambda x: np.quantile(x, 0.75),
         lambda x: np.quantile(x, 0.9)]
# only use train split for aggregation, no leakage
randomState = 0
y = train_df['expense']
X = train_df
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                     y,                                                                                  
                                                     test_size=0.3, 
                                                     random_state=randomState)

X_train, X_valid, y_train, y_valid = train_test_split(X_train, 
                                                        y_train,                                                                                     
                                                        test_size=0.15, 
                                                        random_state=randomState)

for col in ['state','occupation']:
    stats = X_train['expense'].groupby(X_train[col]).agg(f_list)
    train_df = pd.merge(train_df.reset_index(names='id'), stats, how='left', on=[col]).set_index('id')
    train_df = train_df.drop(columns=[col])
    train_df = train_df.rename(columns={'mean': col+'_mean',
                                       '<lambda_0>': col+'_q1',
                                       '<lambda_1>': col+'_q2',
                                       '<lambda_2>': col+'_q3',
                                       '<lambda_3>': col+'_q4',
                                       '<lambda_4>': col+'_q5'})


    test_df = pd.merge(test_df.reset_index(names='id'), stats, how='left', on=[col]).set_index('id')
    test_df = test_df.drop(columns=[col])
    test_df = test_df.rename(columns={'mean': col+'_mean',
                                       '<lambda_0>': col+'_q1',
                                       '<lambda_1>': col+'_q2',
                                       '<lambda_2>': col+'_q3',
                                       '<lambda_3>': col+'_q4',
                                       '<lambda_4>': col+'_q5'})

    newNumCols.extend([col+'_mean',col+'_q1',col+'_q2',col+'_q3',col+'_q4',col+'_q5'])    
    remCatCols.append(col)
    
train_df['education_per_familySize'] = train_df['education']/train_df['familysize']
train_df['age_per_familySize'] =  train_df['age']/train_df['familysize']
train_df['education_per_income'] =  train_df['education']/(train_df['income']+1)
train_df['AnnualExpenditureByFamilySize_per_education'] =  train_df['AnnualExpenditureByFamilySize']/(train_df['education']+1)
train_df['AnnualExpenditureByAge_per_familysize'] =  train_df['AnnualExpenditureByAge']/(train_df['familysize'])
train_df['CPIUrban_times_familySize'] = train_df['CPIUrban']*train_df['familysize']

test_df['education_per_familySize'] = test_df['education']/test_df['familysize']
test_df['age_per_familySize'] =  test_df['age']/test_df['familysize']
test_df['education_per_income'] =  test_df['education']/(test_df['income']+1)
test_df['AnnualExpenditureByFamilySize_per_education'] =  test_df['AnnualExpenditureByFamilySize']/(test_df['education']+1)
test_df['AnnualExpenditureByAge_per_familysize'] =  test_df['AnnualExpenditureByAge']/(test_df['familysize'])
test_df['CPIUrban_times_familySize'] = test_df['CPIUrban']*test_df['familysize']

newNumCols.extend(['education_per_familySize',
                'age_per_familySize',
                'education_per_income',
               'AnnualExpenditureByFamilySize_per_education',
               'AnnualExpenditureByAge_per_familysize',
               'CPIUrban_times_familySize'])

train_df = train_df.drop(columns=['daysInMonth'])
train_df = train_df.drop(columns=['daysInPrevMonth'])
test_df = test_df.drop(columns=['daysInMonth'])
test_df = test_df.drop(columns=['daysInPrevMonth'])

remNumCols.extend(['daysInMonth', 'daysInPrevMonth'])

# %%
# make sure everything is float
numericalCols.extend(newNumCols)
numericalCols = np.setdiff1d(numericalCols, remNumCols)

train_df[numericalCols] = train_df[numericalCols].astype('float')
test_df[numericalCols] = test_df[numericalCols].astype('float')

catCols = np.setdiff1d(catCols, remCatCols)

# %%
train_df.to_csv(path_or_buf=os.path.join(path, 'train_augmented_engineered.csv'), index=True, index_label='id')
test_df.to_csv(path_or_buf=os.path.join(path, 'test_augmented_engineered.csv'), index=True, index_label='id')
